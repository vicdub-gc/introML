# %%
class LogisticRegression(nn.Module):
    """Baseline logistic regression model"""

    def __init__(self) -> None:
        super().__init__()
        # Input tensor is of shape [batch_size, 6, 160, 160]
        self.conv1 = nn.Conv2d(6, 12, kernel_size=3)
        self.fc1 = nn.Linear(12*79*79, 1)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = x.flatten(start_dim=1)
        out = self.fc1(x)
        return out
    #val_acc = 0.719

# %%
class LogisticRegression(nn.Module):
    """Baseline logistic regression model"""

    def __init__(self) -> None:
        super().__init__()
        # Input tensor is of shape [batch_size, 6, 160, 160]
        self.conv1 = nn.Conv2d(6, 12, kernel_size=3)
        self.fc1 = nn.Linear(12*79*79, 100)
        self.fc2 = nn.Linear(100,10)
        self.fc3 = nn.Linear(10,1)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = x.flatten(start_dim=1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        out = self.fc3(x)
        
        return out
    #lr=5e-3
    #epoch=12
        #0.862

# %%
class LogisticRegression(nn.Module):
    """Baseline logistic regression model"""

    def __init__(self) -> None:
        super().__init__()
        # Input tensor is of shape [batch_size, 6, 160, 160]
        self.conv1 = nn.Conv2d(6, 12, kernel_size=3)
        self.conv2 = nn.Conv2d(12, 24, kernel_size=2)
        self.conv3 = nn.Conv2d(24, 48, kernel_size=2)
        self.conv4 = nn.Conv2d(48, 96, kernel_size=2)
        
        self.fc1 = nn.Linear(96*9*9, 1000)
        self.fc2 = nn.Linear(1000,100)
        self.fc3 = nn.Linear(100,1)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv3(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2)
        x = x.flatten(start_dim=1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        out = self.fc3(x)
        
        return out
    #val=0.914
    #batch =64
    # Adam lr=3e-3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dbe77e463f3d> in <module>
# ----> 1 class LogisticRegression(nn.Module):
#       2     """Baseline logistic regression model"""
#       3
#       4     def __init__(self) -> None:
#       5         super().__init__()
#
# NameError: name 'nn' is not defined

# %%
#Best config: batch=258,
class LogisticRegression(nn.Module):
    """Baseline logistic regression model"""

    def __init__(self) -> None:
        super().__init__()
        # Input tensor is of shape [batch_size, 6, 160, 160]
        self.conv1 = nn.Conv2d(6, 12, kernel_size=3)
        self.conv2 = nn.Conv2d(12, 24, kernel_size=2)
        self.conv3 = nn.Conv2d(24, 48, kernel_size=2)
        self.conv4 = nn.Conv2d(48, 96, kernel_size=2)
        
        self.fc1 = nn.Linear(96*9*9, 1000)
        self.fc2 = nn.Linear(1000,100)
        self.fc3 = nn.Linear(100,1)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv3(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2)
        x = x.flatten(start_dim=1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        out = self.fc3(x)
        
        return out


loss_fn = torch.nn.BCEWithLogitsLoss().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
scheduler = None 
epochs = 30

# %%
### Jeudi avant rendu

# %%
# New import to do transformations on dataset
import torchvision.transforms as transforms

# %%
# More info about transforms: https://pytorch.org/vision/stable/transforms.html
# In this line we do transformations on our data to have randomer images. It does a generalisation of our dataset. To do so, we applied three different transformations. 
# The two first one are respectively horizontal and vertical flip with a probability of occurrence of 50%. The third one is a random rotation of the image with an angle between 0 and 360 degrees.
# Those transformations are applied on our dataset
transform =  transforms.Compose([transforms.RandomHorizontalFlip(p=0.5), transforms.RandomVerticalFlip(p=0.5), transforms.RandomRotation(degrees = (0,360)),])
#
batch_size = 32

train_csv_path = "data/train.csv"
test_csv_path = "data/test.csv"
pairs_folder_path = "data/patch-pairs"

train_data = PatchPairsDataset(csv_path=train_csv_path, pairs_folder_path=pairs_folder_path, transform=transform)

# Split into train / val using split_dataset() from dataset.py
train_data, val_data = split_dataset(train_data, split=0.2)

test_data = PatchPairsDataset(csv_path=test_csv_path, pairs_folder_path=pairs_folder_path, transform=transform)


train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=4)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False, num_workers=4)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False, num_workers=4)

# %%
# Try implementing new network architectures to improve your performance!
# We use a conventional neural network because it is the neural network that work the best for images.
# There is several conv because we want the most general data possible.
# With we do max pool between to reduc the number of pixel, this would accelerate the working of our code.
# After that we do a classical linear fc  with a good amount of nodes, not to much because the code's running time would be too long.
# And not to short to be sure to keep a maximum of information.

class LogisticRegression(nn.Module):
    """Baseline logistic regression model"""

    def __init__(self) -> None:
        super().__init__()
        # Input tensor is of shape [batch_size, 6, 160, 160]
        
        self.conv1 = nn.Conv2d(6, 12, kernel_size=3)
        self.conv2 = nn.Conv2d(12, 24, kernel_size=2)
        self.conv3 = nn.Conv2d(24, 48, kernel_size=2)
        self.conv4 = nn.Conv2d(48, 96, kernel_size=2)
        
        self.fc1 = nn.Linear(96*9*9, 1000)
        self.fc2 = nn.Linear(1000,1000)
        self.fc3 = nn.Linear(1000,1)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv3(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2)
        x = x.flatten(start_dim=1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        out = self.fc3(x)
        
        return out

# %%
# We keep the loss function of the basic code
loss_fn = torch.nn.BCEWithLogitsLoss().to(device)
# The optimizer is an AdamW, one of the classical optimizer. ...
# The learning rate has been set ... 
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3)
scheduler = None 
epochs = 10
